# %%
# pip install diffusers==0.14.0
# pip install transformers==4.27.4
#conda install pytorch==1.13.1 torchvision==0.14.1 torchaudio==0.13.1 -c pytorch
#pip install omegaconf

# %%
# Download .safetensors from https://civitai.com/models/4823/deliberate

# %%
#Step One: Convert a model from .safetensors to diffusers format
# Out:
# global_step key not found in model
# ...

# %%
# !python convert_original_stable_diffusion_to_diffusers.py --checkpoint_path='/Users/megan.bultema/Documents/image_diffusion/hackingtogether-megan/deliberate_v2.safetensors' --dump_path='converted_model_deliberate/' --from_safetensors
